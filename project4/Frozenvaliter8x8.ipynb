deltas_8 = [0.002, 0.3333333333333333, 0.17777777777777776, 0.0916543209876543, 0.05562469135802468, 0.03512783539094652, 0.02164356116445665, 0.013313606935528119, 0.007901150985118274, 0.004648216763066315, 0.0031670886009616123, 0.002114611594043029, 0.001504310339312611, 0.0010435367224911757]

# %%
plt.plot(range(len(deltas_99)-1), deltas_99[1:], label='Gamma = 0.99')
plt.plot(range(len(deltas_9)-1), deltas_9[1:], label='Gamma = 0.9')
plt.plot(range(len(deltas_8)-1), deltas_8[1:], label='Gamma = 0.8')
plt.plot(range(len(deltas_99)-1), [theta] * len(deltas_99[1:]), label='Theta = 0.001')
plt.xlabel('Iterations', fontsize=18)
plt.ylabel('Change', fontsize=18)
plt.legend(loc='best')

# %%
theta = 0.01
deltas_99 = [0.02, 0.3333333333333333, 0.21999999999999997, 0.156453, 0.11993973750000003, 0.10543272527700001, 0.08724448073888913, 0.07145712677670912, 0.060687415402881695, 0.05105205717026001, 0.04294279381394095, 0.03887096828167766, 0.03635875691913598, 0.034398186072454706, 0.03324054813201041, 0.03169195690945764, 0.030596760263591982, 0.029691924214834187, 0.028564465851643905, 0.02796953655465953, 0.02727903428343645, 0.02669478839349798, 0.026080717524330638, 0.02536652713833512, 0.02443443810404594, 0.023346055338546945, 0.022156768972412755, 0.021076286930043653, 0.020005556139748137, 0.018891389752381305, 0.017763418683204357, 0.016644343151739016, 0.015550965292320917, 0.014496327781698182, 0.013489975255089937, 0.012537347714924818, 0.01164070785118404, 0.010800170307506185, 0.010014499772765917]
deltas_9 = [0.02, 0.3333333333333333, 0.19999999999999998, 0.12299999999999997, 0.08459999999999998, 0.06428699999999996, 0.04553091000000001, 0.033532542, 0.024208354980000013, 0.01726286973659999, 0.012865309417421991, 0.010380347379273153]
deltas_8 = [0.02, 0.3333333333333333, 0.17777777777777776, 0.0916543209876543, 0.05562469135802468, 0.03512783539094652, 0.02164356116445665, 0.013313606935528119]

# %%
plt.plot(range(len(deltas_99)-1), deltas_99[1:], label='Gamma = 0.99')
plt.plot(range(len(deltas_9)-1), deltas_9[1:], label='Gamma = 0.9')
plt.plot(range(len(deltas_8)-1), deltas_8[1:], label='Gamma = 0.8')
plt.plot(range(len(deltas_99)-1), [theta] * len(deltas_99[1:]), label='Theta = 0.01')
plt.xlabel('Iterations', fontsize=18)
plt.ylabel('Change', fontsize=18)
plt.legend(loc='best')
